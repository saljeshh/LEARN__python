# %%
import os

# this is show all attributes of os module
#print(dir(os))

# current working directory
print(os.getcwd())

# Change directory
# os.chdir('/02_Data analytics projects/')
print(os.getcwd())
# Out:
# d:\02_Data analytics projects
# d:\02_Data analytics projects

# %%
import os

print(os.getcwd())
print(os.listdir())

# change dir back to corey
os.chdir('../00_Corey Schafter Begineer Series/')

print(os.getcwd())
print(os.listdir())

# mkdir is used for only making one level or one data
os.mkdir('os-demo-1')

# makedirs is used to create top level as well as sub directory
os.makedirs('os-demo-2/sub-dir-1')

print(os.listdir())
# Out:
# d:\00_Corey Schafter Begineer Series
# ['.git', '01_strings.ipynb', '02_Integer&Floats.ipynb', '03_List_Tuples_Sets.ipynb', '04_Dictionary.ipynb', '05_ifstatements.ipynb', '06_loops.ipynb', '07_Functions.ipynb', '08_intro.ipynb', '09_os_module.ipynb', 'my_module.py', 'os-demo-2', '__pycache__']
# d:\00_Corey Schafter Begineer Series
# ['.git', '01_strings.ipynb', '02_Integer&Floats.ipynb', '03_List_Tuples_Sets.ipynb', '04_Dictionary.ipynb', '05_ifstatements.ipynb', '06_loops.ipynb', '07_Functions.ipynb', '08_intro.ipynb', '09_os_module.ipynb', 'my_module.py', 'os-demo-2', '__pycache__']
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[19], line 16
#      13 os.mkdir('os-demo-1')
#      15 # makedirs is used to create top level as well as sub directory
# ---> 16 os.makedirs('os-demo-2/sub-dir-1')
#      18 print(os.listdir())
#
# ...

# %%
import os

# deleting
os.rmdir('os-demo-1')

os.removedirs('os-demo-2/sub-dir-1/')

# %%
import os

os.makedirs('10_datetime.ipynb')
os.rename('10_datetime.ipynb','demo.txt')

# %%
import os
from datetime import datetime

print(os.stat('demo.txt'))

modified_time  = os.stat('demo.txt').st_mtime
print(datetime.fromtimestamp(modified_time))
# Out:
# os.stat_result(st_mode=16895, st_ino=1125899906845983, st_dev=3021711149, st_nlink=1, st_uid=0, st_gid=0, st_size=0, st_atime=1678026984, st_mtime=1678026791, st_ctime=1678026791)
# 2023-03-05 20:18:11.791085

# %%
# see all dir tree
import os

for dirpath, dirnames, filenames in os.walk('../02_Data analytics projects/'):
    print('Current Path: ',dirpath)
    print('Directories: ', dirnames)
    print('Files: ', filenames)
    print()
# Out:
# Current Path:  ../02_Data analytics projects/
# Directories:  ['Bigmart sales', 'Bikesales Data Analysis', 'Bitcoin Data Analysis', 'Ecommerce Sales Data Analysis', 'Music Data Analysis', 'SalarySales', 'Superstore sales Data']
# Files:  ['~$notes.docx']
#
# Current Path:  ../02_Data analytics projects/Bigmart sales
# Directories:  []
# Files:  ['bigmart-cleaned.csv', 'bigmart-raw.csv']
#
# Current Path:  ../02_Data analytics projects/Bikesales Data Analysis
# Directories:  []
# Files:  ['cleaned-data.csv', 'dashboard-pivottable.xlsx', 'RAW-bikereport.csv']
#
# Current Path:  ../02_Data analytics projects/Bitcoin Data Analysis
# Directories:  ['.git']
# Files:  ['BTC.pbix', 'BTC.png', 'cleaned-data.csv', 'Raw-bitcoin-data.csv']
#
# Current Path:  ../02_Data analytics projects/Bitcoin Data Analysis\.git
# Directories:  ['hooks', 'info', 'logs', 'objects', 'refs']
# Files:  ['COMMIT_EDITMSG', 'config', 'description', 'HEAD', 'index']
#
# ...

# %%
# Environment variables - add HOME in env variables

import os

print(os.environ.get('HOME'))

# we can do this way but we might miss \\ in the path 
file_path = os.environ.get('HOME') + 'text.txt'
print(file_path)

# so we use now 
new_file_path = os.path.join(os.environ.get('HOME'),'new.txt')
print(new_file_path)

# 
os.path.basename('/tmp/text.txt')
os.path.dirname('temp/test.txt')
os.path.split('temp/main.txt')

print(os.path.exists('/temp/hawa.js')) # false
print(os.path.isdir('/temp'))
print(os.path.isfile('main.js'))

print(os.path.splitext('/tmp/test.txt'))
# Out:
# C:\Users\Saljesh Maharjan\Downloads
# C:\Users\Saljesh Maharjan\Downloadstext.txt
# C:\Users\Saljesh Maharjan\Downloads\new.txt
# False
# False
# False
# ('/tmp/test', '.txt')
